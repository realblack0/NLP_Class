# %% [markdown]
# # WPM (Word Piece Model)

# %%
from collections import defaultdict

# %%
# BPE (Byte Pair Encoding)

data = {
    "low":5,
    "lowest":2,
    "newer":6,
    "wider":3
}

pair = defaultdict()
for k, v in data.items():
    print(list(k) + ["</w>"])# </w>는 단어의 끝임을 알려주는 임의의 태그.

    break
# Out:
# ['l', 'o', 'w', '</w>']

# %% [raw]
# "low" 5 => "lo" 5, "ow" 5, "w</w>" 5
# "lower" 2 => "lo" 2, ...
# "lo" => 7

# %%
# BPE (Byte Pair Encoding)

data = {
    "low":5,
    "lowest":2,
    "newer":6,
    "wider":3
}

n = 2
pair = defaultdict(int)
for k, v in data.items():
    tokens = list(k) + ["</w>"] # </w>는 단어의 끝임을 알려주는 임의의 태그.
    for i in range(len(tokens) - (n-1)):
        pair[tuple(tokens[i:i+n])] = v

# %%
pair
# Out:
# defaultdict(int,
#             {('l', 'o'): 2,
#              ('o', 'w'): 2,
#              ('w', '</w>'): 5,
#              ('w', 'e'): 6,
#              ('e', 's'): 2,
#              ('s', 't'): 2,
#              ('t', '</w>'): 2,
#              ('n', 'e'): 6,
#              ('e', 'w'): 6,
#              ('e', 'r'): 3,
#              ('r', '</w>'): 3,
#              ('w', 'i'): 3,
#              ('i', 'd'): 3,
#              ('d', 'e'): 3})

# %%
pair[('e', 'r')]
# Out:
# 3

# %%
# BPE (Byte Pair Encoding)

data = {
    "low":5,
    "lowest":2,
    "newer":6,
    "wider":3
}

n = 2
pair = defaultdict()
for k, v in data.items():
    tokens = list(k) + ["</w>"] # </w>는 단어의 끝임을 알려주는 임의의 태그.
    for i in range(len(tokens) - (n-1)):
        pair[tuple(tokens[i:i+n])] = v

maxKey = "".join(max(pair, key=pair.get))

# %%
maxKey
# Out:
# 'we'

# %%
import re

# %%
# BPE (Byte Pair Encoding)

data = {
    "l o w </w>":5,
    "l o w e s t </w>":2,
    "n e w e r </w>":6,
    "w i d e r </w>":3
}

n = 2 # 모든 이웃 음절쌍 찾기(bigram) => 빈도 누적
pair = defaultdict(int)
for k, v in data.items():
    tokens = k.split()
    for i in range(len(tokens) - (n-1)):
        pair[tuple(tokens[i:i+n])] = v

# 찾은 쌍 중에 빈도가 가장 높은 한 쌍(패턴)
maxKey = max(pair, key=pair.get)

newData = dict() # 원본 데이터에서 패턴이 일치하면 합치기
for k, v in data.items():
    newK = re.sub(" ".join(maxKey), "".join(maxKey), k)
    newData[newK] = v

# %%
newData
# Out:
# {'l o w </w>': 5,
#  'l o we s t </w>': 2,
#  'n e we r </w>': 6,
#  'w i d e r </w>': 3}

# %%
# BPE (Byte Pair Encoding)

data = {
    "l o w </w>":5,
    "l o w e s t </w>":2,
    "n e w e r </w>":6,
    "w i d e r </w>":3
}

# 여러번 반복
for _ in range(4):
    n = 2 # 모든 이웃 음절쌍 찾기(bigram) => 빈도 누적
    pair = defaultdict(int)
    for k, v in data.items():
        tokens = k.split()
        for i in range(len(tokens) - (n-1)):
            pair[tuple(tokens[i:i+n])] += v

    # 찾은 쌍 중에 빈도가 가장 높은 한 쌍(패턴)
    maxKey = max(pair, key=pair.get)

    newData = dict() # 원본 데이터에서 패턴이 일치하면 합치기
    for k, v in data.items():
        newK = re.sub(" ".join(maxKey), "".join(maxKey), k)
        newData[newK] = v
    
    data = newData

# %%
data
# Out:
# {'low </w>': 5, 'low e s t </w>': 2, 'n e w er</w>': 6, 'w i d er</w>': 3}

# %%
pair[('e', 'r')], pair
# Out:
# (0,
#  defaultdict(int,
#              {('lo', 'w'): 7,
#               ('w', '</w>'): 5,
#               ('w', 'e'): 2,
#               ('e', 's'): 2,
#               ('s', 't'): 2,
#               ('t', '</w>'): 2,
#               ('n', 'e'): 6,
#               ('e', 'w'): 6,
#               ('w', 'er</w>'): 6,
#               ('w', 'i'): 3,
#               ('i', 'd'): 3,
#               ('d', 'er</w>'): 3,
#               ('e', 'r'): 0}))

# %% [markdown]
# > 너무 많이 반복시키면 모든 단어가 다 붙어버리는 문제가 생긴다.
# >
# > 언어마다 적절한 반복횟수가 다르다.

# %%
# 제한 걸기

# BPE (Byte Pair Encoding)

data = {
    "l o w </w>":5,
    "l o w e s t </w>":2,
    "n e w e r </w>":6,
    "w i d e r </w>":3
}

threshold = max(data.values())

# 여러번 반복
for _ in range(15):
    n = 2 # 모든 이웃 음절쌍 찾기(bigram) => 빈도 누적
    pair = defaultdict(int)
    for k, v in data.items():
        tokens = k.split()
        for i in range(len(tokens) - (n-1)):
            pair[tuple(tokens[i:i+n])] += v

    # 찾은 쌍 중에 빈도가 가장 높은 한 쌍(패턴)
    maxKey = max(pair, key=pair.get)

    newData = dict() # 원본 데이터에서 패턴이 일치하면 합치기
    for k, v in data.items():
        if pair[maxKey] > threshold:
            newK = re.sub(" ".join(maxKey), "".join(maxKey), k)
        else:
            newK = k
        newData[newK] = v
    
    data = newData

# %%
data
# Out:
# {'low </w>': 5, 'low e s t </w>': 2, 'n e w er</w>': 6, 'w i d er</w>': 3}

# %%
# 의미가 있는 토큰만 남기기.
# 오메 이중 for 컴프리헨션... 어떠케한거지;;

[token for _ in data.keys()
 for token in _.split() 
 if len(_) > 2 and token != "</w>"]
# Out:
# ['low', 'low', 'e', 's', 't', 'n', 'e', 'w', 'er</w>', 'w', 'i', 'd', 'er</w>']

# %%
str2split = lambda s: " ".join(list(s) + ["</w>"])
str2split("국민의")
# Out:
# '국 민 의 </w>'

# %%
def findPair(data, n=2):
    pair = defaultdict(int)
    for k, v in data.items():
        tokens = k.split()
        for i in range(len(tokens) - (n-1)):
            pair[tuple(tokens[i:i+n])] += v
    return pair

# %%
def mergePair(data, maxKey, maxValue,threshold):
    newData = dict()
    for k, v in data.items():
        if maxValue > threshold:
            newK = re.sub(" ".join(maxKey), 
                          "".join(maxKey), k)
        else:
            newK = k
        newData[newK] = v
    return newData

# %%
data = {
    str2split("low") : 5,
    str2split("lowest") : 2,
    str2split("newer") : 6,
    str2split("wider") : 3
}

threshold = max(data.values())

for _ in range(100):
    pair = findPair(data)
    maxKey = max(pair, key=pair.get)
    maxValue = pair[maxKey]
    data = mergePair(data, maxKey, maxValue, threshold)
    
for _ in data.keys():
    for token in _.split():
        if len(token) > 2 and token != "</w>":
            print(token)
# Out:
# low
# low
# er</w>
# er</w>

# %% [markdown]
# # 한글로 해보자

# %%
# steming

data = {
    str2split("국민의") : 5,
    str2split("국민을") : 2,
    str2split("국민에게") : 6,
    str2split("국민은") : 3
}

threshold = max(data.values())

for _ in range(100):
    pair = findPair(data)
    maxKey = max(pair, key=pair.get)
    maxValue = pair[maxKey]
    data = mergePair(data, maxKey, maxValue, threshold)
    
for _ in data.keys():
    for token in _.split():
        if len(token) > 1 and token != "</w>": # 한글은 음절이 중요하므로 1음절 단위로 바꿈
            print(token)
# Out:
# 국민
# 국민
# 국민
# 국민

# %%
from konlpy.corpus import kolaw
corpus = kolaw.open(kolaw.fileids()[0]).read()

# %%
from nltk.tokenize import word_tokenize
tokens = defaultdict(int)
for _ in word_tokenize(corpus):
    tokens[_] += 1

# %%
data = {str2split(k):v for k, v in tokens.items()}
threshold = max(data.values())

for _ in range(100):
    pair = findPair(data)
    maxKey = max(pair, key=pair.get)
    maxValue = pair[maxKey]
    data = mergePair(data, maxKey, maxValue, threshold)
    
for _ in data.keys():
    for token in _.split():
        if len(token) > 1 and token != "</w>": # 한글은 음절이 중요하므로 1음절 단위로 바꿈
            print(token)
# Out:
# .</w>
# .</w>
# .</w>
# .</w>
# 는</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 는</w>
# .</w>
# .</w>
# .</w>
# 는</w>
# 의</w>
# .</w>
# .</w>
# 는</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 의</w>
# 의</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# 는</w>
# .</w>
# .</w>
# .</w>
# 는</w>
# 는</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 는</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 는</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# 는</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 는</w>
# .</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# .</w>
# 는</w>
# 는</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 는</w>
# 의</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 는</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 의</w>
# 는</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 의</w>
# 는</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# 는</w>
# .</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# 는</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# 는</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# 의</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# 의</w>
# .</w>
# 의</w>
# 는</w>
# .</w>
# 는</w>
# .</w>
# .</w>
# 의</w>
# 의</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 는</w>
# 의</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 는</w>
# .</w>
# .</w>
# .</w>
# 는</w>
# 의</w>
# .</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# 의</w>
# 는</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 는</w>
# 의</w>
# 는</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 는</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 는</w>
# 의</w>
# .</w>
# .</w>
# 는</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 는</w>
# .</w>
# .</w>
# 는</w>
# 의</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 는</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 는</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# 는</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# 의</w>
# 의</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# 의</w>
# 는</w>
# .</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 는</w>
# 의</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 는</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# 는</w>
# 의</w>
# .</w>
# 의</w>
# 는</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 는</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# 는</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 의</w>
# 의</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# 는</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# 의</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 는</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 의</w>
# 는</w>
# .</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 의</w>
# 는</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 는</w>
# .</w>
# .</w>
# .</w>
# 는</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# 의</w>
# 는</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 는</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# 의</w>
# 의</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 는</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# 는</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# 의</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 는</w>
# .</w>
# 의</w>
# 의</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# .</w>
# 는</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# 는</w>
# .</w>
# 의</w>
# 의</w>
# .</w>
# 의</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 의</w>
# 의</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# .</w>
# 의</w>
# 는</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# 는</w>
# 의</w>
# 는</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 의</w>
# 는</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 의</w>
# 의</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 는</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# .</w>
# 는</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# 의</w>
# 는</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 는</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# 는</w>
# .</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# 는</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 의</w>
# 의</w>
# .</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 는</w>
# .</w>
# 는</w>
# .</w>
# .</w>
# .</w>
# 의</w>
# 의</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# .</w>
# 는</w>
# .</w>
# 는</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# 는</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# 는</w>
# 는</w>
# 는</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 의</w>
# 의</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 의</w>
# 의</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# 의</w>
# 의</w>
# .</w>
# 의</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 는</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# .</w>
# 는</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# 는</w>
# .</w>
# 의</w>
# .</w>
# 의</w>
# .</w>
# 의</w>
# .</w>
# 의</w>
# .</w>
# 의</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 는</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 의</w>
# 의</w>
# 의</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# 의</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# .</w>
# 는</w>
# .</w>
# 의</w>
# .</w>
# 는</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# 의</w>
# 는</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 는</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# 의</w>
# 의</w>
# 의</w>
# 의</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 는</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# 는</w>
# 의</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# 는</w>
# 는</w>
# 의</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 는</w>
# 는</w>
# 의</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# 는</w>
# 의</w>
# .</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# 는</w>
# 의</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 는</w>
# 의</w>
# .</w>
# .</w>
# .</w>
# 의</w>
# 는</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# 의</w>
# 의</w>
# .</w>
# .</w>
# .</w>
# 는</w>
# 의</w>
# 의</w>
# .</w>
# .</w>
# .</w>
# 는</w>
# .</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# 의</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# 의</w>
# 의</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# 의</w>
# 는</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 는</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 는</w>
# .</w>
# .</w>
# 의</w>
# 는</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 는</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 는</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# .</w>
# 의</w>
# .</w>
# .</w>
# .</w>

# %% [markdown]
# > 한글에서는 잘 안되네... 전부 </w>로 되어 있구나.
# >
# > corpus의 양이 부족해서 그럴 수 있다.
# >
# > threshold를 낮추면 될 수도 있겠다.

# %%
data = {str2split(k):v for k, v in tokens.items()}
# threshold = max(data.values())
threshold = sum(data.values())/len(data) # 평균

for _ in range(100):
    pair = findPair(data)
    maxKey = max(pair, key=pair.get)
    maxValue = pair[maxKey]
    data = mergePair(data, maxKey, maxValue, threshold)
    
tokens_ = list()
for _ in data.keys():
    for token in _.split():
        if len(token) > 1 and token != "</w>" and \
        not token.endswith("</w>"): # 한글은 음절이 중요하므로 1음절 단위로 바꿈
            tokens_.append(token)

# %%
len(set(tokens_)), len(data), set(tokens_)
# Out:
# (31,
#  1617,
#  {'경제',
#   '국가',
#   '국무',
#   '국무총',
#   '국민',
#   '국회',
#   '노력',
#   '대통',
#   '대통령',
#   '대한',
#   '법관',
#   '법률',
#   '보장',
#   '보호',
#   '선거',
#   '아니',
#   '위원',
#   '임기',
#   '임명',
#   '재적',
#   '재판',
#   '정당',
#   '제1',
#   '제2',
#   '제3',
#   '제4',
#   '조직',
#   '하여',
#   '행정',
#   '헌법',
#   '헌법재판'})

# %% [markdown]
# ---

# %%
import os

tokens = defaultdict(int)
basedir = "practice/8일차_실습_project/헤드라인/"

for file in [_ for _ in os.listdir(basedir)
            if _.startswith("정치-")]:
    with open(basedir+file, encoding="utf-8") as fp:
        corpus = fp.read()
        
    for _ in word_tokenize(corpus):
        tokens[_] += 1

# %%
data = {str2split(k):v for k, v in tokens.items()}
# threshold = max(data.values())
threshold = sum(data.values())/len(data) # 평균

for _ in range(100):
    pair = findPair(data)
    maxKey = max(pair, key=pair.get)
    maxValue = pair[maxKey]
    data = mergePair(data, maxKey, maxValue, threshold)
    
tokens_ = list()
for _ in data.keys():
    for token in _.split():
        if len(token) > 1 and token != "</w>" and \
        not token.endswith("</w>"): # 한글은 음절이 중요하므로 1음절 단위로 바꿈
            tokens_.append(token)

# %%
len(set(tokens_)), len(data), set(tokens_)
# Out:
# (32,
#  4138,
#  {'.co',
#   '.co.k',
#   '.k',
#   '17',
#   '20',
#   '201',
#   '2017',
#   '9.',
#   'al',
#   'as',
#   'flas',
#   're',
#   'ti',
#   'un',
#   '다.',
#   '대통',
#   '대통령',
#   '대표',
#   '법무',
#   '보훈',
#   '삭발',
#   '서울',
#   '연합',
#   '우회',
#   '의원',
#   '이라',
#   '자유',
#   '장관',
#   '콘텐츠',
#   '한국',
#   '했다.',
#   '혁신'})
